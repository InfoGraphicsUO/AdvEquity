# %%
import geopandas as gpd
import numpy as np

# %%
import os

# %%
os.chdir(r"C:\Users\iboardma\Desktop\adv_equity\frontend\AdvEquity\assets")
print(os.getcwd())
# Out:
# C:\Users\iboardma\Desktop\adv_equity\frontend\AdvEquity\assets

# %%
all_dists = gpd.read_file("data\shapefiles\EDGE_SCHOOLDISTRICT_TL24_SY2324\EDGE_SCHOOLDISTRICT_TL24_SY2324.shp")

# %%
all_dists.head()
# Out:
#   STATEFP ELSDLEA SCSDLEA UNSDLEA SDADMLEA    GEOID  \
# 0      04    None   07530    None     None  0407530
# 1      04    None   01740    None     None  0401740
# 2      04    None   01160    None     None  0401160
# 3      04    None   00720    None     None  0400720
# 4      04    None   09630    None     None  0409630
#
#                                            NAME LSAD LOGRADE HIGRADE  MTFCC  \
# 0  Santa Cruz Valley Union High School District   00      09      12  G5410
# 1        Casa Grande Union High School District   00      09      12  G5410
# 2       Bicentennial Union High School District   00      09      12  G5410
# 3           Antelope Union High School District   00      09      12  G5410
# 4               Yuma Union High School District   00      09      12  G5410
#
#   SDTYP FUNCSTAT         ALAND      AWATER     INTPTLAT      INTPTLON  \
# 0  None        E  1.856958e+09   3443532.0  +32.6418079  -111.4345331
# ...

# %%
oregon = all_dists[all_dists['STATEFP'] == '41']

# %%
oregon
# Out:
#       STATEFP ELSDLEA SCSDLEA UNSDLEA SDADMLEA    GEOID  \
# 439        41    None   03630    None     None  4103630
# 2329       41   03600    None    None     None  4103600
# 2330       41   04170    None    None     None  4104170
# 2331       41   04290    None    None     None  4104290
# 2332       41   04380    None    None     None  4104380
# ...       ...     ...     ...     ...      ...      ...
# 10386      41    None    None   13350     None  4113350
# 10387      41    None    None   13490     None  4113490
# 10388      41    None    None   13530     None  4113530
# 10389      41    None    None   13650     None  4113650
# 10390      41    None    None   99997     None  4199997
#
#                                               NAME LSAD LOGRADE HIGRADE  \
# 439    Harney County Union High School District 1J   00      09      12
# 2329               Harney County School District 4   00      KG      08
# 2330                     Diamond School District 7   00      KG      08
# ...

# %%
oregon = oregon.to_crs(epsg=4326)
oregon.to_file("data/geojson/oregon_districts.geojson", driver="GeoJSON")
